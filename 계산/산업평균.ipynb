# %%
import pandas as pd

# %%
# 기업별.년도별.산업평균매출원가율
df = pd.read_csv('./전체데이터_2011_KOSPI+KOSDAQ_매출원가율_산업평균.csv')
df
# Out:
#             구분      코드                             산업명    2011년    2012년  \
# 0     (주)CMG제약   58820                의료용 물질 및 의약품 제조업    58.17    71.66
# 1     (주)DB하이텍     990    전자부품, 컴퓨터, 영상, 음향 및 통신장비 제조업    82.94     83.4
# 2      (주)ES큐브   50120                     도매 및 상품 중개업    69.79    71.64
# 3     (주)HJ중공업   97230                     기타 운송장비 제조업    93.13        0
# 4     (주)MH에탄올   23150                          음료 제조업    75.72    77.99
# ...        ...     ...                             ...      ...      ...
# 2018   휴림로봇(주)   90710                  기타 기계 및 장비 제조업    75.88    79.03
# 2019   휴마시스(주)  205470                           기타금융업  #DIV/0!  #DIV/0!
# 2020     휴젤(주)  145020                의료용 물질 및 의약품 제조업  #DIV/0!  #DIV/0!
# 2021   흥구석유(주)   24060                     도매 및 상품 중개업    96.29    96.91
# 2022   흥아해운(주)    3280                          수상 운송업    98.56    93.05
#
#         2013년    2014년  2015년    2016년  2017년   2018년   2019년
# ...

# %%
df2 = pd.read_csv('C:/Users/user/Desktop/프로젝트2/데이터/data/회생전략/산업분류코드중간값.csv',encoding='cp949')
df2

# %%
#결측치 0으로 대체 
df1 = df.replace('#DIV/0!',0)
# Out:
#             구분      코드                             산업명  2011년  2012년  2013년  \
# 0     (주)CMG제약   58820                의료용 물질 및 의약품 제조업  58.17  71.66  61.54
# 1     (주)DB하이텍     990    전자부품, 컴퓨터, 영상, 음향 및 통신장비 제조업  82.94   83.4  81.92
# 2      (주)ES큐브   50120                     도매 및 상품 중개업  69.79  71.64  74.25
# 3     (주)HJ중공업   97230                     기타 운송장비 제조업  93.13      0  98.63
# 4     (주)MH에탄올   23150                          음료 제조업  75.72  77.99  71.81
# ...        ...     ...                             ...    ...    ...    ...
# 2018   휴림로봇(주)   90710                  기타 기계 및 장비 제조업  75.88  79.03  88.22
# 2019   휴마시스(주)  205470                           기타금융업      0      0      0
# 2020     휴젤(주)  145020                의료용 물질 및 의약품 제조업      0      0      0
# 2021   흥구석유(주)   24060                     도매 및 상품 중개업  96.29  96.91  96.72
# 2022   흥아해운(주)    3280                          수상 운송업  98.56  93.05  95.03
#
#       2014년  2015년  2016년  2017년   2018년   2019년
# ...

# %%
# 같은 값을 하나로 묶어 통계 또는 집계를 얻기 위해 사용하는 함수 groupby

# %%
print(df1.median())
# Out:
# 코드       60590.00
# 2011년       70.79
# 2012년       72.38
# 2013년       73.66
# 2014년       74.78
# 2015년       75.17
# 2016년       76.59
# 2017년       77.43
# 2018년       79.38
# 2019년       79.47
# dtype: float64
# C:\Users\user\AppData\Local\Temp\ipykernel_3464\1852948138.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   print(df1.median())

# %%
df2.to_csv('산업중간값.csv',encoding='CP949')

# %%
if df['산업명']== '의료용 물질 및 의약품 제조업':
    print('df[2011].median()')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\user\Desktop\프로젝트2\데이터\data\회생전략\산업평균.ipynb 셀 3 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/user/Desktop/%ED%94%84%EB%A1%9C%EC%A0%9D%ED%8A%B82/%EB%8D%B0%EC%9D%B4%ED%84%B0/data/%ED%9A%8C%EC%83%9D%EC%A0%84%EB%9E%B5/%EC%82%B0%EC%97%85%ED%8F%89%EA%B7%A0.ipynb#W2sZmlsZQ%3D%3D?line=0'>1</a> if df['산업명']== '의료용 물질 및 의약품 제조업':
#       <a href='vscode-notebook-cell:/c%3A/Users/user/Desktop/%ED%94%84%EB%A1%9C%EC%A0%9D%ED%8A%B82/%EB%8D%B0%EC%9D%B4%ED%84%B0/data/%ED%9A%8C%EC%83%9D%EC%A0%84%EB%9E%B5/%EC%82%B0%EC%97%85%ED%8F%89%EA%B7%A0.ipynb#W2sZmlsZQ%3D%3D?line=1'>2</a>     print('df[2011].median()')
#
# File c:\Users\user\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\generic.py:1527, in NDFrame.__nonzero__(self)
#    1525 @final
#    1526 def __nonzero__(self):
# ...

# %%
df2 = df.groupby(['산업명']).median()
df2
