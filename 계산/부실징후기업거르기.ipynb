# %% [markdown]
# ## 1년연속 부실징후기업 거르기

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("C:/Users/user/Desktop/프로젝트2/데이터/data/회생전략/운용적.자산적 범주의 전략/매출원가축소/매출원가율.csv",encoding='cp949')
df
# Out:
#        Unnamed: 0       회사명  거래소코드    회계년도  매출원가(*)(IFRS)(천원)  \
# 0               0  (주)CMG제약  58820  Dec-10          8217627.0
# 1               1  (주)CMG제약  58820  Dec-11         10325799.0
# 2               2  (주)CMG제약  58820  Dec-12         11648690.0
# 3               3  (주)CMG제약  58820  Dec-13         12506817.0
# 4               4  (주)CMG제약  58820  Dec-14         14318048.0
# ...           ...       ...    ...     ...                ...
# 16498       16498   흥아해운(주)   3280  Dec-15        763642673.0
# 16499       16499   흥아해운(주)   3280  Dec-16        756984914.0
# 16500       16500   흥아해운(주)   3280  Dec-17        778062692.0
# 16501       16501   흥아해운(주)   3280  Dec-18        724528226.0
# 16502       16502   흥아해운(주)   3280  Dec-19         98752599.0
#
#        매출액(수익)(*)(IFRS연결)(천원)  매출원가(*)(IFRS연결)(천원)
# 0                  11350419.0            8217627.0
# 1                  17751704.0           10325799.0
# 2                  16255389.0           11648690.0
# ...

# %%
df1 = pd.read_csv("C:/Users/user/Desktop/프로젝트2/데이터/data/회생전략/운용적.자산적 범주의 전략/매출원가축소/1년연속부실징후기업.csv",encoding='cp949')
df1
# Out:
#            회사명  거래소코드    회계년도
# 0     (주)CMG제약  58820  11-Dec
# 1     (주)CMG제약  58820  12-Dec
# 2     (주)CMG제약  58820  13-Dec
# 3     (주)CMG제약  58820  14-Dec
# 4     (주)CMG제약  58820  15-Dec
# ...        ...    ...     ...
# 9448   흥아해운(주)   3280  14-Dec
# 9449   흥아해운(주)   3280  15-Dec
# 9450   흥아해운(주)   3280  16-Dec
# 9451   흥아해운(주)   3280  17-Dec
# 9452   흥아해운(주)   3280  18-Dec
#
# [9453 rows x 3 columns]

# %%
df2 = df1.merge(df,how="left")
df2
# Out:
#            회사명  거래소코드    회계년도  Unnamed: 0 매출액(수익)(*)(IFRS연결)(천원)  \
# 0     (주)CMG제약  58820  11-Dec         0.0               17751704
# 1     (주)CMG제약  58820  12-Dec         1.0               16255389
# 2     (주)CMG제약  58820  13-Dec         2.0               20402140
# 3     (주)CMG제약  58820  14-Dec         3.0               22752584
# 4     (주)CMG제약  58820  15-Dec         4.0               27041894
# ...        ...    ...     ...         ...                    ...
# 9448   흥아해운(주)   3280  14-Dec     15144.0              825144979
# 9449   흥아해운(주)   3280  15-Dec     15145.0              845115359
# 9450   흥아해운(주)   3280  16-Dec     15146.0              831746081
# 9451   흥아해운(주)   3280  17-Dec     15147.0              836427496
# 9452   흥아해운(주)   3280  18-Dec     15148.0              753865569
#
#      매출원가(*)(IFRS연결)(천원)  매출원가율
# 0               10325799   0.58
# 1               11648690   0.72
# 2               12506817   0.61
# 3               14318048   0.63
# ...

# %%
df2.to_csv("1년연속부실징후기업매출원가율.csv",encoding='cp949')
