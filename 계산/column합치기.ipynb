# %%
import pandas as pd

# %%
df = pd.read_csv("C:/Users/user/Desktop/프로젝트2/데이터/data/회생전략/전체데이터_R&D투자효율비용비율계산용.csv",encoding='cp949')
df
# Out:
#             회사명  거래소코드    회계년도  이자보상배율  총자산증가율  유형자산증가율  유동자산증가율  재고자산증가율  \
# 0      (주)CMG제약  58820  11-Dec    3.53    1.98    -5.90    17.64    -1.43
# 1      (주)CMG제약  58820  12-Dec   -7.75  109.15    -4.12   207.08     7.73
# 2      (주)CMG제약  58820  13-Dec    0.70   -2.09    16.09   -18.89    56.29
# 3      (주)CMG제약  58820  14-Dec    3.60    3.86    74.30   -25.93     6.37
# 4      (주)CMG제약  58820  15-Dec  -32.22   -2.64    -5.37    -7.17    11.04
# ...         ...    ...     ...     ...     ...      ...      ...      ...
# 15145   흥아해운(주)   3280  15-Dec    1.02   21.93    49.36   -11.18   -12.92
# 15146   흥아해운(주)   3280  16-Dec    0.21   21.08    38.84   -25.08    56.39
# 15147   흥아해운(주)   3280  17-Dec   -0.42  -11.43   -16.50    13.29    11.18
# 15148   흥아해운(주)   3280  18-Dec   -1.16   -5.33   -12.07    -6.33    -5.85
# 15149   흥아해운(주)   3280  19-Dec    0.00  -46.38   -51.51   -13.42   -58.98
#
#        자기자본증가율      순이익증가율  ...       자본집약도  설비투자효율  총자본투자효율  부가가치율  종업원수증가율  \
# ...

# %%
df['회사명'] = df['회사명'].str.replace("(주)","")
df['회사명'] = df['회사명'].str.replace("\(","")
df['회사명'] = df['회사명'].str.replace("\)","")
df
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_19396\100570597.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['회사명'] = df['회사명'].str.replace("(주)","")
# C:\Users\user\AppData\Local\Temp\ipykernel_19396\100570597.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['회사명'] = df['회사명'].str.replace("\(","")
# C:\Users\user\AppData\Local\Temp\ipykernel_19396\100570597.py:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['회사명'] = df['회사명'].str.replace("\)","")
#          회사명  거래소코드    회계년도  이자보상배율  총자산증가율  유형자산증가율  유동자산증가율  재고자산증가율  \
# 0      CMG제약  58820  11-Dec    3.53    1.98    -5.90    17.64    -1.43
# 1      CMG제약  58820  12-Dec   -7.75  109.15    -4.12   207.08     7.73
# 2      CMG제약  58820  13-Dec    0.70   -2.09    16.09   -18.89    56.29
# 3      CMG제약  58820  14-Dec    3.60    3.86    74.30   -25.93     6.37
# ...

# %%
df1=pd.read_csv("C:/Users/user/Desktop/프로젝트2/데이터/data/회생전략/매출액.csv",encoding='cp949')
df1
# Out:
#       Unnamed: 0    회사명    회계년도  거래소코드  매출액(수익)(*)(IFRS연결)(천원)
# 0              0  CMG제약  11-Dec  58820                17751704
# 1              1  CMG제약  12-Dec  58820                16255389
# 2              2  CMG제약  13-Dec  58820                20402140
# 3              3  CMG제약  14-Dec  58820                22752584
# 4              4  CMG제약  15-Dec  58820                27041894
# ...          ...    ...     ...    ...                     ...
# 9024        9024   흥아해운  14-Dec   3280               825144979
# 9025        9025   흥아해운  15-Dec   3280               845115359
# 9026        9026   흥아해운  16-Dec   3280               831746081
# 9027        9027   흥아해운  17-Dec   3280               836427496
# 9028        9028   흥아해운  18-Dec   3280               753865569
#
# [9029 rows x 5 columns]

# %%
# # # merge("A","B",how="left")했는데 안돼서 A.merge(B,how="left")했더니 됨!^^ 
# df2 = pd.merge(df1, df, on=['회사명','거래소코드'])
# df2
df2= df1.merge(df,how='left')
df2
# Out:
#       Unnamed: 0    회사명    회계년도  거래소코드  매출액(수익)(*)(IFRS연결)(천원)  이자보상배율  \
# 0              0  CMG제약  11-Dec  58820                17751704    3.53
# 1              1  CMG제약  12-Dec  58820                16255389   -7.75
# 2              2  CMG제약  13-Dec  58820                20402140    0.70
# 3              3  CMG제약  14-Dec  58820                22752584    3.60
# 4              4  CMG제약  15-Dec  58820                27041894  -32.22
# ...          ...    ...     ...    ...                     ...     ...
# 9024        9024   흥아해운  14-Dec   3280               825144979    1.12
# 9025        9025   흥아해운  15-Dec   3280               845115359    1.02
# 9026        9026   흥아해운  16-Dec   3280               831746081    0.21
# 9027        9027   흥아해운  17-Dec   3280               836427496   -0.42
# 9028        9028   흥아해운  18-Dec   3280               753865569   -1.16
#
#       총자산증가율  유형자산증가율  유동자산증가율  재고자산증가율  ...       자본집약도  설비투자효율  총자본투자효율  \
# ...

# %%
df2.to_csv("1년연속부실징후기업_KOSPI+KOSDAQ_R&D투자효율부문비율계산완료.csv",encoding='cp949')
