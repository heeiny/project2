# %%
import pandas as pd

# %%
df = pd.read_csv("C:/Users/user/Desktop/프로젝트2/데이터/data/신성장기업\PAT.csv",encoding="cp949")
df
# Out:
#        Unnamed: 0 통계청 한국표준산업분류 10차(중분류)       회사명   거래소코드    회계년도  \
# 0               0      의료용 물질 및 의약품 제조업  (주)CMG제약   58820  11-Dec
# 1               1      의료용 물질 및 의약품 제조업  (주)CMG제약   58820  12-Dec
# 2               2      의료용 물질 및 의약품 제조업  (주)CMG제약   58820  13-Dec
# 3               3      의료용 물질 및 의약품 제조업  (주)CMG제약   58820  14-Dec
# 4               4      의료용 물질 및 의약품 제조업  (주)CMG제약   58820  15-Dec
# ...           ...                   ...       ...     ...     ...
# 37257       42707      의료용 물질 및 의약품 제조업   휴마시스(주)  205470  15-Dec
# 37258       42708      의료용 물질 및 의약품 제조업   휴마시스(주)  205470  16-Dec
# 37259       42709      의료용 물질 및 의약품 제조업   휴마시스(주)  205470  17-Dec
# 37260       42710      의료용 물질 및 의약품 제조업   휴마시스(주)  205470  18-Dec
# 37261       42711      의료용 물질 및 의약품 제조업   휴마시스(주)  205470  19-Dec
#
#        이자보상배율(이자비용)(IFRS)  이자보상배율(이자비용)(IFRS연결)  이자보상배율  R&D투자효율  고용증가율  \
# 0                    3.94                  3.53    3.53     1.41   1.41
# ...

# %%
dataframe = df.drop(['Unnamed: 0'],axis=1)
dataframe
# Out:
#       통계청 한국표준산업분류 10차(중분류)       회사명   거래소코드    회계년도  이자보상배율(이자비용)(IFRS)  \
# 0          의료용 물질 및 의약품 제조업  (주)CMG제약   58820  11-Dec                3.94
# 1          의료용 물질 및 의약품 제조업  (주)CMG제약   58820  12-Dec               -7.45
# 2          의료용 물질 및 의약품 제조업  (주)CMG제약   58820  13-Dec                0.73
# 3          의료용 물질 및 의약품 제조업  (주)CMG제약   58820  14-Dec                3.63
# 4          의료용 물질 및 의약품 제조업  (주)CMG제약   58820  15-Dec              -32.20
# ...                     ...       ...     ...     ...                 ...
# 37257      의료용 물질 및 의약품 제조업   휴마시스(주)  205470  15-Dec         77777777.77
# 37258      의료용 물질 및 의약품 제조업   휴마시스(주)  205470  16-Dec         77777777.77
# 37259      의료용 물질 및 의약품 제조업   휴마시스(주)  205470  17-Dec                1.55
# 37260      의료용 물질 및 의약품 제조업   휴마시스(주)  205470  18-Dec               -3.93
# 37261      의료용 물질 및 의약품 제조업   휴마시스(주)  205470  19-Dec               -1.10
#
#        이자보상배율(이자비용)(IFRS연결)  이자보상배율  R&D투자효율  고용증가율  경상개발비율  연구개발비율
# ...
