# %%
import pandas as pd

# %%
#총자산대비자본율dataframe
df = pd.read_csv('C:/Users/user/Desktop/프로젝트2/데이터/data/회생전략/재무적 범주의 전략/총자산대비자본/총자산대비자본율.csv',encoding='cp949')
# df_ = df.drop(['Unnamed: 8','Unnamed: 9'],axis=1)
df_
# Out:
#             회사명  거래소코드    회계년도 자산(*)(IFRS)(천원) 자본(*)(IFRS)(천원)  \
# 0      (주)CMG제약  58820  10-Dec          26,776          18,405
# 1      (주)CMG제약  58820  11-Dec          27,549          18,291
# 2      (주)CMG제약  58820  12-Dec          56,989          31,603
# 3      (주)CMG제약  58820  13-Dec          55,962          49,048
# 4      (주)CMG제약  58820  14-Dec          58,127          49,067
# ...         ...    ...     ...             ...             ...
# 19484   흥아해운(주)   3280  15-Dec         771,212         161,825
# 19485   흥아해운(주)   3280  16-Dec         942,587         183,829
# 19486   흥아해운(주)   3280  17-Dec         834,107         107,615
# 19487   흥아해운(주)   3280  18-Dec         782,787          56,732
# 19488   흥아해운(주)   3280  19-Dec         386,551          17,632
#
#       자산(*)(IFRS연결)(천원) 자본(*)(IFRS연결)(천원)  자본율(개별)
# 0                26,776            18,405      NaN
# 1                27,305            18,034      NaN
# 2                57,108            31,591      NaN
# ...

# %%
#2년 연속 한계기업
df1=pd.read_csv('C:/Users/user/Desktop/프로젝트2/데이터/data/전체데이터/전체데이터_2년연속성한계기업.csv',encoding='cp949')
# df1_ = df1.drop(['Unnamed: 6','Unnamed: 7','Unnamed: 8','Unnamed: 9','Unnamed: 10'],axis=1)
df1_
# Out:
#            회사명  거래소코드    회계년도  이자보상배율(이자비용)(IFRS)  이자보상배율(이자비용)(IFRS연결)  \
# 0     (주)CMG제약  58820  11-Dec                3.94                  3.53
# 1     (주)CMG제약  58820  12-Dec               -7.45                 -7.75
# 2     (주)CMG제약  58820  13-Dec                0.73                  0.70
# 3     (주)CMG제약  58820  14-Dec                3.63                  3.60
# 4     (주)CMG제약  58820  15-Dec              -32.20                -32.22
# ...        ...    ...     ...                 ...                   ...
# 6464   흥아해운(주)   3280  14-Dec                0.96                  1.12
# 6465   흥아해운(주)   3280  15-Dec                0.79                  1.02
# 6466   흥아해운(주)   3280  16-Dec                0.04                  0.21
# 6467   흥아해운(주)   3280  17-Dec               -0.61                 -0.42
# 6468   흥아해운(주)   3280  18-Dec               -1.26                 -1.16
#
#       이자보상배율
# 0       3.53
# 1      -7.75
# 2       0.70
# 3       3.60
# 4     -32.22
# ...      ...
# ...

# %%
df2 = pd.merge(df_, df1_)
df2
# Out:
#            회사명  거래소코드    회계년도 자산(*)(IFRS)(천원) 자본(*)(IFRS)(천원)  \
# 0     (주)CMG제약  58820  11-Dec          27,549          18,291
# 1     (주)CMG제약  58820  12-Dec          56,989          31,603
# 2     (주)CMG제약  58820  13-Dec          55,962          49,048
# 3     (주)CMG제약  58820  14-Dec          58,127          49,067
# 4     (주)CMG제약  58820  15-Dec          56,592          46,873
# ...        ...    ...     ...             ...             ...
# 6452   흥아해운(주)   3280  14-Dec         627,805         153,936
# 6453   흥아해운(주)   3280  15-Dec         771,212         161,825
# 6454   흥아해운(주)   3280  16-Dec         942,587         183,829
# 6455   흥아해운(주)   3280  17-Dec         834,107         107,615
# 6456   흥아해운(주)   3280  18-Dec         782,787          56,732
#
#      자산(*)(IFRS연결)(천원) 자본(*)(IFRS연결)(천원)  자본율(개별)  이자보상배율(이자비용)(IFRS)  \
# 0               27,305            18,034      NaN                3.94
# 1               57,108            31,591      NaN               -7.45
# ...

# %%
df2.to_csv("2년연속한계기업_총자본율.csv",encoding='CP949')
