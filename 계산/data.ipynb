# %%
import pandas as pd

# %%
df=pd.read_csv('C:/Users/user/Desktop/프로젝트2/데이터/data/수명주기/전체데이터_2011_KOSPI+KOSDAQ_수명주기_label.csv',encoding='cp949')
df
# Out:
#        Unnamed: 0       회사명  거래소코드    회계년도  영업활동으로 인한 현금흐름(간접법)(*)(IFRS)(천원)  \
# 0               0  (주)CMG제약  58820  Dec-11                        -2488268.0
# 1               1  (주)CMG제약  58820  Dec-12                        -1453276.0
# 2               2  (주)CMG제약  58820  Dec-13                        -3891420.0
# 3               3  (주)CMG제약  58820  Dec-14                          730447.0
# 4               4  (주)CMG제약  58820  Dec-15                         2411254.0
# ...           ...       ...    ...     ...                               ...
# 15145       15145   흥아해운(주)   3280  Dec-15                        34042933.0
# 15146       15146   흥아해운(주)   3280  Dec-16                        -4725664.0
# 15147       15147   흥아해운(주)   3280  Dec-17                        -5348563.0
# 15148       15148   흥아해운(주)   3280  Dec-18                       -30464257.0
# 15149       15149   흥아해운(주)   3280  Dec-19                       -16943933.0
#
# ...

# %%
df.drop(columns='Unnamed: 0',axis=0)
# Out:
#             회사명  거래소코드    회계년도  영업활동으로 인한 현금흐름(간접법)(*)(IFRS)(천원)  \
# 0      (주)CMG제약  58820  Dec-11                        -2488268.0
# 1      (주)CMG제약  58820  Dec-12                        -1453276.0
# 2      (주)CMG제약  58820  Dec-13                        -3891420.0
# 3      (주)CMG제약  58820  Dec-14                          730447.0
# 4      (주)CMG제약  58820  Dec-15                         2411254.0
# ...         ...    ...     ...                               ...
# 15145   흥아해운(주)   3280  Dec-15                        34042933.0
# 15146   흥아해운(주)   3280  Dec-16                        -4725664.0
# 15147   흥아해운(주)   3280  Dec-17                        -5348563.0
# 15148   흥아해운(주)   3280  Dec-18                       -30464257.0
# 15149   흥아해운(주)   3280  Dec-19                       -16943933.0
#
#        투자활동으로 인한 현금흐름(*)(IFRS)(천원)  재무활동으로 인한 현금흐름(*)(IFRS)(천원)  \
# 0                       -1845332.0                    3038758.0
# ...

# %%
for i in range(0, len(df)):
    if df.iloc[i]['기업수명(연결)'] == '8':
        df.loc[i, '기업수명(연결)'] = df.iloc[i]['기업수명']

# %%
df
# Out:
#        Unnamed: 0       회사명  거래소코드    회계년도  영업활동으로 인한 현금흐름(간접법)(*)(IFRS)(천원)  \
# 0               0  (주)CMG제약  58820  Dec-11                        -2488268.0
# 1               1  (주)CMG제약  58820  Dec-12                        -1453276.0
# 2               2  (주)CMG제약  58820  Dec-13                        -3891420.0
# 3               3  (주)CMG제약  58820  Dec-14                          730447.0
# 4               4  (주)CMG제약  58820  Dec-15                         2411254.0
# ...           ...       ...    ...     ...                               ...
# 15145       15145   흥아해운(주)   3280  Dec-15                        34042933.0
# 15146       15146   흥아해운(주)   3280  Dec-16                        -4725664.0
# 15147       15147   흥아해운(주)   3280  Dec-17                        -5348563.0
# 15148       15148   흥아해운(주)   3280  Dec-18                       -30464257.0
# 15149       15149   흥아해운(주)   3280  Dec-19                       -16943933.0
#
# ...

# %%
df.to_csv('기업수명주기_code적용.csv',encoding='CP949')

# %%
df['기업수명(연결)'].value_counts()
# Out:
# 성숙기    5249
# 성장기    4300
# 도입기    2214
# 쇄신기    1780
# 쇠퇴기    1217
# 8       204
# 9       185
# Name: 기업수명(연결), dtype: int64
