# %%
import pandas as pd

# %%
df = pd.read_csv('C:/Users/user/Desktop/프로젝트2/데이터/data/전체데이터/02_1년연속성부실징후기업.csv',encoding='cp949')
df
# Out:
#            회사명  거래소코드    회계년도  이자보상배율  총자산증가율  유형자산증가율  유동자산증가율  재고자산증가율  \
# 0     (주)CMG제약  58820  11-Dec    3.53    1.98    -5.91    17.64    -1.43
# 1     (주)CMG제약  58820  12-Dec   -7.75  109.15    -4.12   207.08     7.73
# 2     (주)CMG제약  58820  13-Dec    0.70   -2.09    16.09   -18.89    56.29
# 3     (주)CMG제약  58820  14-Dec    3.60    3.86    74.30   -25.93     6.37
# 4     (주)CMG제약  58820  15-Dec  -32.22   -2.64    -5.37    -7.17    11.04
# ...        ...    ...     ...     ...     ...      ...      ...      ...
# 9448   흥아해운(주)   3280  14-Dec    1.12   13.69    45.19   -13.68    -8.50
# 9449   흥아해운(주)   3280  15-Dec    1.02   21.93    49.36   -11.18   -12.92
# 9450   흥아해운(주)   3280  16-Dec    0.21   21.08    38.84   -25.08    56.39
# 9451   흥아해운(주)   3280  17-Dec   -0.42  -11.43   -16.50    13.29    11.18
# 9452   흥아해운(주)   3280  18-Dec   -1.16   -5.33   -12.07    -6.33    -5.85
#
#       자기자본증가율   순이익증가율  ...  노동소득분배율  설비투자효율  총자본투자효율   기계투자효율  부가가치율  \
# ...

# %%
grouped_ww = df.groupby(['sex', 'length_cat','rings'])['whole_weight']
# Out:
#   Input In [34]
#     df_x = pd.DataFrame(df[['회사명']].groupby(df['통계청 한국표준산업분류 10차(소분류)']).agg(df['통계청 한국표준산업분류 10차(소분류)']value_counts(), df['경상개발비(천원)'].count_values()))
#                                                                                                         ^
# SyntaxError: invalid syntax

# %%
import numpy as np
df_z = df.loc[df["무형자산처리무형자산개발비(천원)"].values != 0]
df_z
# Out:
#            회사명  거래소코드    회계년도       이자보상배율  총자산증가율  유형자산증가율  유동자산증가율  재고자산증가율  \
# 2     (주)CMG제약  58820  13-Dec         0.70   -2.09    16.09   -18.89    56.29
# 3     (주)CMG제약  58820  14-Dec         3.60    3.86    74.30   -25.93     6.37
# 4     (주)CMG제약  58820  15-Dec       -32.22   -2.64    -5.37    -7.17    11.04
# 5     (주)CMG제약  58820  16-Dec  11111111.11   96.31    -5.14   199.84    17.20
# 6     (주)CMG제약  58820  17-Dec  11111111.11   -1.27    -4.28     3.12    23.63
# ...        ...    ...     ...          ...     ...      ...      ...      ...
# 9448   흥아해운(주)   3280  14-Dec         1.12   13.69    45.19   -13.68    -8.50
# 9449   흥아해운(주)   3280  15-Dec         1.02   21.93    49.36   -11.18   -12.92
# 9450   흥아해운(주)   3280  16-Dec         0.21   21.08    38.84   -25.08    56.39
# 9451   흥아해운(주)   3280  17-Dec        -0.42  -11.43   -16.50    13.29    11.18
# 9452   흥아해운(주)   3280  18-Dec        -1.16   -5.33   -12.07    -6.33    -5.85
#
# ...

# %%
import numpy as np
df_z = df.loc[df["무형자산처리무형자산개발비(천원)"].values != 0]
df_y = df_z.loc[~(df_z["무형자산처리무형자산개발비(천원)"].isna())]

df_x = pd.DataFrame(df_z.groupby(['통계청 한국표준산업분류 10차(소분류)']).count())
df_x
# Out:
#                        회사명  거래소코드  회계년도  이자보상배율  총자산증가율  유형자산증가율  유동자산증가율  \
# 통계청 한국표준산업분류 10차(소분류)
#   1차 비철금속 제조업           22     22    22      22      22       22       22
#   1차 철강 제조업            146    146   146     146     146      146      146
#   가전제품 및 정보통신장비 소매업      3      3     3       3       3        3        3
#   가정용 기기 제조업             2      2     2       2       2        2        2
#   건물 건설업                48     48    48      48      48       48       48
# ...                    ...    ...   ...     ...     ...      ...      ...
#   해상 운송업                33     33    33      33      33       33       33
#   해체, 선별 및 원료 재생업        9      9     9       9       9        9        9
#   화학섬유 제조업               9      9     9       9       9        9        9
#   환경 정화 및 복원업            3      3     3       3       3        3        3
#   회사 본부 및 경영 컨설팅 서비스업  170    170   170     170     170      169      170
#
# ...

# %%
df_z
# Out:
#            회사명  거래소코드    회계년도       이자보상배율  총자산증가율  유형자산증가율  유동자산증가율  재고자산증가율  \
# 2     (주)CMG제약  58820  13-Dec         0.70   -2.09    16.09   -18.89    56.29
# 3     (주)CMG제약  58820  14-Dec         3.60    3.86    74.30   -25.93     6.37
# 4     (주)CMG제약  58820  15-Dec       -32.22   -2.64    -5.37    -7.17    11.04
# 5     (주)CMG제약  58820  16-Dec  11111111.11   96.31    -5.14   199.84    17.20
# 6     (주)CMG제약  58820  17-Dec  11111111.11   -1.27    -4.28     3.12    23.63
# ...        ...    ...     ...          ...     ...      ...      ...      ...
# 9448   흥아해운(주)   3280  14-Dec         1.12   13.69    45.19   -13.68    -8.50
# 9449   흥아해운(주)   3280  15-Dec         1.02   21.93    49.36   -11.18   -12.92
# 9450   흥아해운(주)   3280  16-Dec         0.21   21.08    38.84   -25.08    56.39
# 9451   흥아해운(주)   3280  17-Dec        -0.42  -11.43   -16.50    13.29    11.18
# 9452   흥아해운(주)   3280  18-Dec        -1.16   -5.33   -12.07    -6.33    -5.85
#
# ...

# %%
df.isna().sum()
# Out:
# 회사명                         0
# 거래소코드                       0
# 회계년도                        0
# 이자보상배율                      0
# 총자산증가율                    136
# 유형자산증가율                   138
# 유동자산증가율                   136
# 재고자산증가율                   613
# 자기자본증가율                   136
# 순이익증가율                   2609
# 매출액총이익율                   144
# 매출액순이익율                   144
# 자기자본순이익율                  144
# 총자본정상영업이익율                144
# 매출액정상영업이익율                144
# 총자본순이익율                   144
# 총자본회전율                    448
# 재고자산회전율                   826
# 매출채권회전율                   510
# 유형자산회전율                   448
# 매입채무회전율                   738
# 자기자본회전율                   448
# 타인자본회전율                   448
# 유동자산회전율                  2675
# 유동비율                      144
# 당좌비율                      144
# 현금비율                      144
# 부채비율                      144
# 차입금의존도                    144
# CASH_FLOW_대_부채비율          144
# CASH_FLOW_대_매출액비율         144
# ...
